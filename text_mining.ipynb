# %% [markdown]
# <a href="https://colab.research.google.com/github/abhinavgadikar/marketing_analytics-text_mining/blob/main/text_mining.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install nltk scikit-learn pandas wordcloud matplotlib seaborn

# %%
import nltk
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# True

# %%
# Import necessary libraries
import pandas as pd
import matplotlib.pyplot as plt
from wordcloud import WordCloud
from sklearn.feature_extraction.text import CountVectorizer
import nltk
from nltk.corpus import stopwords
import string

# Ensure NLTK stopwords are downloaded
nltk.download('stopwords')

# Sample Text Data
# Replace this with your actual text data
# For example, Text can be a list of documents
Text = [
    "This is the first document.",
    "This document is the second document.",
    "And this is the third one.",
    "Is this the first document?"
]

# Define custom stopwords
custom_stopwords = set(["blabla1", "blabla2"])

# Combine English stopwords with custom stopwords
stop_words = set(stopwords.words('english')).union(custom_stopwords)

# Function to preprocess text
def preprocess_text(text):
    # Convert to lowercase
    text = text.lower()
    # Remove numbers
    text = ''.join([char for char in text if not char.isdigit()])
    # Remove punctuation
    text = text.translate(str.maketrans('', '', string.punctuation))
    # Remove stopwords
    tokens = text.split()
    tokens = [word for word in tokens if word not in stop_words]
    return ' '.join(tokens)

# Clean the text
cleaned_text = [preprocess_text(doc) for doc in Text]

# Create a Term-Document Matrix using CountVectorizer
vectorizer = CountVectorizer()
term_doc_matrix = vectorizer.fit_transform(cleaned_text)

# Get the frequency of each word
term_freq = term_doc_matrix.toarray().sum(axis=0)
terms = vectorizer.get_feature_names_out()
freq_df = pd.DataFrame({'word': terms, 'freq': term_freq})

# Sort the DataFrame by frequency in descending order
freq_df = freq_df.sort_values(by='freq', ascending=False).reset_index(drop=True)

# Display the top 10 most frequent words
print(freq_df.head(10))

# Save the frequency DataFrame to a CSV file
freq_df.to_csv("text.csv", index=False)

# Generate the Word Cloud
plt.figure(figsize=(10, 8))
wordcloud = WordCloud(
    width=800,
    height=400,
    background_color='white',
    max_words=200,
    colormap='Dark2',
    random_state=1234
).generate_from_frequencies(freq_df.set_index('word')['freq'])

plt.imshow(wordcloud, interpolation='bilinear')
plt.axis('off')
plt.tight_layout(pad=0)
plt.show()

# Explore frequent terms with a minimum frequency of 4
# (Adjust the threshold based on your data)
frequent_terms = freq_df[freq_df['freq'] >= 4]
print("Frequent terms with frequency >= 4:")
print(frequent_terms)
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
#        word  freq
# 0  document     4
# 1     first     2
# 2       one     1
# 3    second     1
# 4     third     1
# Frequent terms with frequency >= 4:
#        word  freq
# 0  document     4

# %%
# prompt: Modify the above script to allow me to upload a text file as input.

import nltk
import pandas as pd
import matplotlib.pyplot as plt
from wordcloud import WordCloud
from sklearn.feature_extraction.text import CountVectorizer
from nltk.corpus import stopwords
import string
from google.colab import files

# Ensure NLTK stopwords are downloaded
nltk.download('stopwords')

# Function to preprocess text
def preprocess_text(text):
    # Convert to lowercase
    text = text.lower()
    # Remove numbers
    text = ''.join([char for char in text if not char.isdigit()])
    # Remove punctuation
    text = text.translate(str.maketrans('', '', string.punctuation))
    # Remove stopwords
    tokens = text.split()
    tokens = [word for word in tokens if word not in stop_words]
    return ' '.join(tokens)

# Define custom stopwords
custom_stopwords = set(["blabla1", "blabla2"])

# Combine English stopwords with custom stopwords
stop_words = set(stopwords.words('english')).union(custom_stopwords)


# Upload a text file
uploaded = files.upload()

# Get the filename from the uploaded file
filename = list(uploaded.keys())[0]

# Open and read the text file
with open(filename, 'r') as file:
    Text = file.readlines()

# Clean the text
cleaned_text = [preprocess_text(doc) for doc in Text]

# Create a Term-Document Matrix using CountVectorizer
vectorizer = CountVectorizer()
term_doc_matrix = vectorizer.fit_transform(cleaned_text)

# Get the frequency of each word
term_freq = term_doc_matrix.toarray().sum(axis=0)
terms = vectorizer.get_feature_names_out()
freq_df = pd.DataFrame({'word': terms, 'freq': term_freq})

# Sort the DataFrame by frequency in descending order
freq_df = freq_df.sort_values(by='freq', ascending=False).reset_index(drop=True)

# Display the top 10 most frequent words
print(freq_df.head(10))

# Save the frequency DataFrame to a CSV file
freq_df.to_csv("text.csv", index=False)

# Generate the Word Cloud
plt.figure(figsize=(10, 8))
wordcloud = WordCloud(
    width=800,
    height=400,
    background_color='white',
    max_words=200,
    colormap='Dark2',
    random_state=1234
).generate_from_frequencies(freq_df.set_index('word')['freq'])

plt.imshow(wordcloud, interpolation='bilinear')
plt.axis('off')
plt.tight_layout(pad=0)
plt.show()

# Explore frequent terms with a minimum frequency of 4
# (Adjust the threshold based on your data)
frequent_terms = freq_df[freq_df['freq'] >= 4]
print("Frequent terms with frequency >= 4:")
print(frequent_terms)
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
#      <input type="file" id="files-ba0381da-0d1d-4726-b69a-350476ff5cde" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-ba0381da-0d1d-4726-b69a-350476ff5cde">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# ...

# %%
pip install nltk scikit-learn pandas wordcloud matplotlib seaborn

# %%
# prompt: Modify the above code to allow me to upload data in xlsx format

import nltk
import pandas as pd
import matplotlib.pyplot as plt
from wordcloud import WordCloud
from sklearn.feature_extraction.text import CountVectorizer
from nltk.corpus import stopwords
import string
from google.colab import files
pip install nltk scikit-learn pandas wordcloud matplotlib seaborn openpyxl

nltk.download('stopwords')

# Ensure NLTK stopwords are downloaded
nltk.download('stopwords')

# Define custom stopwords
custom_stopwords = set(["blabla1", "blabla2"])

# Combine English stopwords with custom stopwords
stop_words = set(stopwords.words('english')).union(custom_stopwords)

# Function to preprocess text
def preprocess_text(text):
    # Convert to lowercase
    text = text.lower()
    # Remove numbers
    text = ''.join([char for char in text if not char.isdigit()])
    # Remove punctuation
    text = text.translate(str.maketrans('', '', string.punctuation))
    # Remove stopwords
    tokens = text.split()
    tokens = [word for word in tokens if word not in stop_words]
    return ' '.join(tokens)

# Upload a file (either text or xlsx)
uploaded = files.upload()

# Get the filename from the uploaded file
filename = list(uploaded.keys())[0]

if filename.endswith(".xlsx"):
    # Read data from Excel file
    df = pd.read_excel(filename)
    # Assuming a column named 'text' contains the text data
    if 'text' in df.columns:
        Text = df['text'].tolist()
    else:
        print("Error: No 'text' column found in the Excel file.")
        exit()
elif filename.endswith(".txt"):
    # Open and read the text file
    with open(filename, 'r') as file:
        Text = file.readlines()
else:
    print("Error: Unsupported file format. Please upload a .txt or .xlsx file.")
    exit()

# Clean the text
cleaned_text = [preprocess_text(doc) for doc in Text]

# Create a Term-Document Matrix using CountVectorizer
vectorizer = CountVectorizer()
term_doc_matrix = vectorizer.fit_transform(cleaned_text)

# Get the frequency of each word
term_freq = term_doc_matrix.toarray().sum(axis=0)
terms = vectorizer.get_feature_names_out()
freq_df = pd.DataFrame({'word': terms, 'freq': term_freq})

# Sort the DataFrame by frequency in descending order
freq_df = freq_df.sort_values(by='freq', ascending=False).reset_index(drop=True)

# Display the top 10 most frequent words
print(freq_df.head(10))

# Save the frequency DataFrame to a CSV file
freq_df.to_csv("text.csv", index=False)

# Generate the Word Cloud
plt.figure(figsize=(10, 8))
wordcloud = WordCloud(
    width=800,
    height=400,
    background_color='white',
    max_words=200,
    colormap='Dark2',
    random_state=1234
).generate_from_frequencies(freq_df.set_index('word')['freq'])

plt.imshow(wordcloud, interpolation='bilinear')
plt.axis('off')
plt.tight_layout(pad=0)
plt.show()

# Explore frequent terms with a minimum frequency of 4
# (Adjust the threshold based on your data)
frequent_terms = freq_df[freq_df['freq'] >= 4]
print("Frequent terms with frequency >= 4:")
print(frequent_terms)
# Out:
#   File "<ipython-input-10-93f0a7f0a06f>", line 11
#     pip install nltk scikit-learn pandas wordcloud matplotlib seaborn openpyxl
#         ^
# SyntaxError: invalid syntax

# %%
# prompt: Modify the code to enable file uploads in .xlsx format. resolve all the errors and ask for file uploads

import nltk
import pandas as pd
import matplotlib.pyplot as plt
from wordcloud import WordCloud
from sklearn.feature_extraction.text import CountVectorizer
from nltk.corpus import stopwords
import string
from google.colab import files

# Install necessary libraries
# !pip install nltk scikit-learn pandas wordcloud matplotlib seaborn openpyxl

nltk.download('stopwords')

# Ensure NLTK stopwords are downloaded
nltk.download('stopwords')

# Define custom stopwords
custom_stopwords = set(["blabla1", "blabla2"])

# Combine English stopwords with custom stopwords
stop_words = set(stopwords.words('english')).union(custom_stopwords)

# Function to preprocess text
def preprocess_text(text):
    # Convert to lowercase
    text = text.lower()
    # Remove numbers
    text = ''.join([char for char in text if not char.isdigit()])
    # Remove punctuation
    text = text.translate(str.maketrans('', '', string.punctuation))
    # Remove stopwords
    tokens = text.split()
    tokens = [word for word in tokens if word not in stop_words]
    return ' '.join(tokens)

# Upload a file (either text or xlsx)
uploaded = files.upload()

# Get the filename from the uploaded file
filename = list(uploaded.keys())[0]

if filename.endswith(".xlsx"):
    # Read data from Excel file
    try:
        df = pd.read_excel(filename)
        # Assuming a column named 'text' contains the text data
        if 'text' in df.columns:
            Text = df['text'].tolist()
        else:
            print("Error: No 'text' column found in the Excel file. Please ensure a column named 'text' exists with your text data.")
            exit()
    except Exception as e:
        print(f"Error reading Excel file: {e}")
        exit()
elif filename.endswith(".txt"):
    # Open and read the text file
    try:
        with open(filename, 'r') as file:
            Text = file.readlines()
    except Exception as e:
        print(f"Error reading text file: {e}")
        exit()
else:
    print("Error: Unsupported file format. Please upload a .txt or .xlsx file.")
    exit()

# Clean the text
cleaned_text = [preprocess_text(doc) for doc in Text]

# Create a Term-Document Matrix using CountVectorizer
vectorizer = CountVectorizer()
term_doc_matrix = vectorizer.fit_transform(cleaned_text)

# Get the frequency of each word
term_freq = term_doc_matrix.toarray().sum(axis=0)
terms = vectorizer.get_feature_names_out()
freq_df = pd.DataFrame({'word': terms, 'freq': term_freq})

# Sort the DataFrame by frequency in descending order
freq_df = freq_df.sort_values(by='freq', ascending=False).reset_index(drop=True)

# Display the top 10 most frequent words
print(freq_df.head(10))

# Save the frequency DataFrame to a CSV file
freq_df.to_csv("text.csv", index=False)

# Generate the Word Cloud
plt.figure(figsize=(10, 8))
wordcloud = WordCloud(
    width=800,
    height=400,
    background_color='white',
    max_words=200,
    colormap='Dark2',
    random_state=1234
).generate_from_frequencies(freq_df.set_index('word')['freq'])

plt.imshow(wordcloud, interpolation='bilinear')
plt.axis('off')
plt.tight_layout(pad=0)
plt.show()

# Explore frequent terms with a minimum frequency of 4
# (Adjust the threshold based on your data)
frequent_terms = freq_df[freq_df['freq'] >= 4]
print("Frequent terms with frequency >= 4:")
print(frequent_terms)
# Out:
# ...
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
#      <input type="file" id="files-12b82835-6f6f-447e-b36d-69030f2f63cd" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-12b82835-6f6f-447e-b36d-69030f2f63cd">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# ...

# %%
# Import necessary libraries
import pandas as pd
import matplotlib.pyplot as plt
from wordcloud import WordCloud
from sklearn.feature_extraction.text import CountVectorizer
import nltk
from nltk.corpus import stopwords
import string
from google.colab import files
import io

# Ensure NLTK stopwords are downloaded
nltk.download('stopwords')

# Step 1: Upload an Excel file in Google Colab
uploaded = files.upload()

# Step 2: Read the uploaded .xlsx file using pandas
# Assuming the text data is in a column named 'Text'
file_name = list(uploaded.keys())[0]  # Get the file name
df = pd.read_excel(io.BytesIO(uploaded[file_name]))

# Replace 'Text' with the actual column name containing the text data
# Ensure your Excel file has a column with this name or adjust as needed
Text = df['Text'].astype(str).tolist()

# Define custom stopwords
custom_stopwords = set(["blabla1", "blabla2"])

# Combine English stopwords with custom stopwords
stop_words = set(stopwords.words('english')).union(custom_stopwords)

# Function to preprocess text
def preprocess_text(text):
    # Convert to lowercase
    text = text.lower()
    # Remove numbers
    text = ''.join([char for char in text if not char.isdigit()])
    # Remove punctuation
    text = text.translate(str.maketrans('', '', string.punctuation))
    # Remove stopwords
    tokens = text.split()
    tokens = [word for word in tokens if word not in stop_words]
    return ' '.join(tokens)

# Step 3: Clean the text
cleaned_text = [preprocess_text(doc) for doc in Text]

# Step 4: Create a Term-Document Matrix using CountVectorizer
vectorizer = CountVectorizer()
term_doc_matrix = vectorizer.fit_transform(cleaned_text)

# Get the frequency of each word
term_freq = term_doc_matrix.toarray().sum(axis=0)
terms = vectorizer.get_feature_names_out()
freq_df = pd.DataFrame({'word': terms, 'freq': term_freq})

# Sort the DataFrame by frequency in descending order
freq_df = freq_df.sort_values(by='freq', ascending=False).reset_index(drop=True)

# Display the top 10 most frequent words
print(freq_df.head(10))

# Step 5: Save the frequency DataFrame to a CSV file
freq_df.to_csv("text.csv", index=False)
files.download("text.csv")  # Provide the file for download in Colab

# Step 6: Generate the Word Cloud
plt.figure(figsize=(10, 8))
wordcloud = WordCloud(
    width=800,
    height=400,
    background_color='white',
    max_words=2000,
    colormap='Dark2',
    random_state=1234
).generate_from_frequencies(freq_df.set_index('word')['freq'])

plt.imshow(wordcloud, interpolation='bilinear')
plt.axis('off')
plt.tight_layout(pad=0)
plt.show()

# Step 7: Explore frequent terms with a minimum frequency of 4
frequent_terms = freq_df[freq_df['freq'] >= 4]
print("Frequent terms with frequency >= 4:")
print(frequent_terms)
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
#      <input type="file" id="files-edc0f53d-fe28-474b-b144-aaeb2c144685" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-edc0f53d-fe28-474b-b144-aaeb2c144685">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# ...

# %%
# prompt: Modify the above code and let the user decide the value of "max_words"

import pandas as pd
import matplotlib.pyplot as plt
# Import necessary libraries

# Ensure NLTK stopwords are downloaded
nltk.download('stopwords')

# Step 1: Upload an Excel file in Google Colab
uploaded = files.upload()

# Step 2: Read the uploaded .xlsx file using pandas
# Assuming the text data is in a column named 'Text'
file_name = list(uploaded.keys())[0]  # Get the file name
df = pd.read_excel(io.BytesIO(uploaded[file_name]))

# Replace 'Text' with the actual column name containing the text data
# Ensure your Excel file has a column with this name or adjust as needed
Text = df['Text'].astype(str).tolist()

# Define custom stopwords
custom_stopwords = set(["blabla1", "blabla2"])

# Combine English stopwords with custom stopwords
stop_words = set(stopwords.words('english')).union(custom_stopwords)

# Function to preprocess text
def preprocess_text(text):
    # Convert to lowercase
    text = text.lower()
    # Remove numbers
    text = ''.join([char for char in text if not char.isdigit()])
    # Remove punctuation
    text = text.translate(str.maketrans('', '', string.punctuation))
    # Remove stopwords
    tokens = text.split()
    tokens = [word for word in tokens if word not in stop_words]
    return ' '.join(tokens)

# Step 3: Clean the text
cleaned_text = [preprocess_text(doc) for doc in Text]

# Step 4: Create a Term-Document Matrix using CountVectorizer
vectorizer = CountVectorizer()
term_doc_matrix = vectorizer.fit_transform(cleaned_text)

# Get the frequency of each word
term_freq = term_doc_matrix.toarray().sum(axis=0)
terms = vectorizer.get_feature_names_out()
freq_df = pd.DataFrame({'word': terms, 'freq': term_freq})

# Sort the DataFrame by frequency in descending order
freq_df = freq_df.sort_values(by='freq', ascending=False).reset_index(drop=True)

# Display the top 10 most frequent words
print(freq_df.head(10))

# Step 5: Save the frequency DataFrame to a CSV file
freq_df.to_csv("text.csv", index=False)
files.download("text.csv")  # Provide the file for download in Colab

# Let the user choose the value of max_words
max_words_input = input("Enter the desired maximum number of words for the word cloud: ")

try:
    max_words = int(max_words_input)
except ValueError:
    print("Invalid input. Using default value of 2000.")
    max_words = 2000  # Default value

# Step 6: Generate the Word Cloud
plt.figure(figsize=(10, 8))
wordcloud = WordCloud(
    width=800,
    height=400,
    background_color='white',
    max_words=max_words,
    colormap='Dark2',
    random_state=1234
).generate_from_frequencies(freq_df.set_index('word')['freq'])

plt.imshow(wordcloud, interpolation='bilinear')
plt.axis('off')
plt.tight_layout(pad=0)
plt.show()

# Step 7: Explore frequent terms with a minimum frequency of 4
frequent_terms = freq_df[freq_df['freq'] >= 4]
print("Frequent terms with frequency >= 4:")
print(frequent_terms)
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
#      <input type="file" id="files-b40fe54f-06a7-4b37-b6fd-949a8bad190f" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-b40fe54f-06a7-4b37-b6fd-949a8bad190f">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# ...

# %%
# prompt: Modify the above code. Ask the user if he needs to download the .csv file after the wordcloud is generated

import pandas as pd
import matplotlib.pyplot as plt
# Import necessary libraries

# Ensure NLTK stopwords are downloaded
nltk.download('stopwords')

# Step 1: Upload an Excel file in Google Colab
uploaded = files.upload()

# Step 2: Read the uploaded .xlsx file using pandas
# Assuming the text data is in a column named 'Text'
file_name = list(uploaded.keys())[0]  # Get the file name
df = pd.read_excel(io.BytesIO(uploaded[file_name]))

# Replace 'Text' with the actual column name containing the text data
# Ensure your Excel file has a column with this name or adjust as needed
Text = df['Text'].astype(str).tolist()

# Define custom stopwords
custom_stopwords = set(["blabla1", "blabla2"])

# Combine English stopwords with custom stopwords
stop_words = set(stopwords.words('english')).union(custom_stopwords)

# Function to preprocess text
def preprocess_text(text):
    # Convert to lowercase
    text = text.lower()
    # Remove numbers
    text = ''.join([char for char in text if not char.isdigit()])
    # Remove punctuation
    text = text.translate(str.maketrans('', '', string.punctuation))
    # Remove stopwords
    tokens = text.split()
    tokens = [word for word in tokens if word not in stop_words]
    return ' '.join(tokens)

# Step 3: Clean the text
cleaned_text = [preprocess_text(doc) for doc in Text]

# Step 4: Create a Term-Document Matrix using CountVectorizer
vectorizer = CountVectorizer()
term_doc_matrix = vectorizer.fit_transform(cleaned_text)

# Get the frequency of each word
term_freq = term_doc_matrix.toarray().sum(axis=0)
terms = vectorizer.get_feature_names_out()
freq_df = pd.DataFrame({'word': terms, 'freq': term_freq})

# Sort the DataFrame by frequency in descending order
freq_df = freq_df.sort_values(by='freq', ascending=False).reset_index(drop=True)

# Display the top 10 most frequent words
print(freq_df.head(10))

# Step 5: Save the frequency DataFrame to a CSV file
freq_df.to_csv("text.csv", index=False)

# Let the user choose the value of max_words
max_words_input = input("Enter the desired maximum number of words for the word cloud: ")

try:
    max_words = int(max_words_input)
except ValueError:
    print("Invalid input. Using default value of 2000.")
    max_words = 2000  # Default value

# Step 6: Generate the Word Cloud
plt.figure(figsize=(10, 8))
wordcloud = WordCloud(
    width=800,
    height=400,
    background_color='white',
    max_words=max_words,
    colormap='Dark2',
    random_state=1234
).generate_from_frequencies(freq_df.set_index('word')['freq'])

plt.imshow(wordcloud, interpolation='bilinear')
plt.axis('off')
plt.tight_layout(pad=0)
plt.show()

# Step 7: Explore frequent terms with a minimum frequency of 4
frequent_terms = freq_df[freq_df['freq'] >= 4]
print("Frequent terms with frequency >= 4:")
print(frequent_terms)


# Ask the user if they want to download the CSV file
download_csv = input("Do you want to download the frequency CSV file? (yes/no): ")

if download_csv.lower() == "yes":
    files.download("text.csv")
else:
    print("CSV file not downloaded.")
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
#      <input type="file" id="files-d15d6348-73be-4a85-9f08-69b3947b0921" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-d15d6348-73be-4a85-9f08-69b3947b0921">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# ...

# %%
# prompt: Modify the above code to incorporate the "Yes/No" buttons for .csv download

import pandas as pd
import matplotlib.pyplot as plt
# Import necessary libraries

# Ensure NLTK stopwords are downloaded
nltk.download('stopwords')

# Step 1: Upload an Excel file in Google Colab
uploaded = files.upload()

# Step 2: Read the uploaded .xlsx file using pandas
# Assuming the text data is in a column named 'Text'
file_name = list(uploaded.keys())[0]  # Get the file name
df = pd.read_excel(io.BytesIO(uploaded[file_name]))

# Replace 'Text' with the actual column name containing the text data
# Ensure your Excel file has a column with this name or adjust as needed
Text = df['Text'].astype(str).tolist()

# Define custom stopwords
custom_stopwords = set(["blabla1", "blabla2"])

# Combine English stopwords with custom stopwords
stop_words = set(stopwords.words('english')).union(custom_stopwords)

# Function to preprocess text
def preprocess_text(text):
    # Convert to lowercase
    text = text.lower()
    # Remove numbers
    text = ''.join([char for char in text if not char.isdigit()])
    # Remove punctuation
    text = text.translate(str.maketrans('', '', string.punctuation))
    # Remove stopwords
    tokens = text.split()
    tokens = [word for word in tokens if word not in stop_words]
    return ' '.join(tokens)

# Step 3: Clean the text
cleaned_text = [preprocess_text(doc) for doc in Text]

# Step 4: Create a Term-Document Matrix using CountVectorizer
vectorizer = CountVectorizer()
term_doc_matrix = vectorizer.fit_transform(cleaned_text)

# Get the frequency of each word
term_freq = term_doc_matrix.toarray().sum(axis=0)
terms = vectorizer.get_feature_names_out()
freq_df = pd.DataFrame({'word': terms, 'freq': term_freq})

# Sort the DataFrame by frequency in descending order
freq_df = freq_df.sort_values(by='freq', ascending=False).reset_index(drop=True)

# Display the top 10 most frequent words
print(freq_df.head(10))

# Step 5: Save the frequency DataFrame to a CSV file
freq_df.to_csv("text.csv", index=False)

# Let the user choose the value of max_words
max_words_input = input("Enter the desired maximum number of words for the word cloud: ")

try:
    max_words = int(max_words_input)
except ValueError:
    print("Invalid input. Using default value of 2000.")
    max_words = 2000  # Default value

# Step 6: Generate the Word Cloud
plt.figure(figsize=(10, 8))
wordcloud = WordCloud(
    width=800,
    height=400,
    background_color='white',
    max_words=max_words,
    colormap='Dark2',
    random_state=1234
).generate_from_frequencies(freq_df.set_index('word')['freq'])

plt.imshow(wordcloud, interpolation='bilinear')
plt.axis('off')
plt.tight_layout(pad=0)
plt.show()

# Step 7: Explore frequent terms with a minimum frequency of 4
frequent_terms = freq_df[freq_df['freq'] >= 4]
print("Frequent terms with frequency >= 4:")
print(frequent_terms)

# Create a Yes/No button for downloading the CSV
download_csv = True  #@param {type:"boolean"}

if download_csv:
    files.download("text.csv")
else:
    print("CSV file not downloaded.")
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
#      <input type="file" id="files-f8816ca1-5897-4da9-9627-c88975c257af" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-f8816ca1-5897-4da9-9627-c88975c257af">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# ...

# %%
# prompt: In the way you have incorporated "yes/no"button, provide the option to decide frequency of words.

import pandas as pd
import matplotlib.pyplot as plt
# Import necessary libraries

# Ensure NLTK stopwords are downloaded
nltk.download('stopwords')

# Step 1: Upload an Excel file in Google Colab
uploaded = files.upload()

# Step 2: Read the uploaded .xlsx file using pandas
# Assuming the text data is in a column named 'Text'
file_name = list(uploaded.keys())[0]  # Get the file name
df = pd.read_excel(io.BytesIO(uploaded[file_name]))

# Replace 'Text' with the actual column name containing the text data
# Ensure your Excel file has a column with this name or adjust as needed
Text = df['Text'].astype(str).tolist()

# Define custom stopwords
custom_stopwords = set(["blabla1", "blabla2"])

# Combine English stopwords with custom stopwords
stop_words = set(stopwords.words('english')).union(custom_stopwords)

# Function to preprocess text
def preprocess_text(text):
    # Convert to lowercase
    text = text.lower()
    # Remove numbers
    text = ''.join([char for char in text if not char.isdigit()])
    # Remove punctuation
    text = text.translate(str.maketrans('', '', string.punctuation))
    # Remove stopwords
    tokens = text.split()
    tokens = [word for word in tokens if word not in stop_words]
    return ' '.join(tokens)

# Step 3: Clean the text
cleaned_text = [preprocess_text(doc) for doc in Text]

# Step 4: Create a Term-Document Matrix using CountVectorizer
vectorizer = CountVectorizer()
term_doc_matrix = vectorizer.fit_transform(cleaned_text)

# Get the frequency of each word
term_freq = term_doc_matrix.toarray().sum(axis=0)
terms = vectorizer.get_feature_names_out()
freq_df = pd.DataFrame({'word': terms, 'freq': term_freq})

# Sort the DataFrame by frequency in descending order
freq_df = freq_df.sort_values(by='freq', ascending=False).reset_index(drop=True)

# Display the top 10 most frequent words
print(freq_df.head(10))

# Step 5: Save the frequency DataFrame to a CSV file
freq_df.to_csv("text.csv", index=False)

# Let the user choose the value of max_words
max_words_input = input("Enter the desired maximum number of words for the word cloud: ")

try:
    max_words = int(max_words_input)
except ValueError:
    print("Invalid input. Using default value of 2000.")
    max_words = 2000  # Default value

# Step 6: Generate the Word Cloud
plt.figure(figsize=(10, 8))
wordcloud = WordCloud(
    width=800,
    height=400,
    background_color='white',
    max_words=max_words,
    colormap='Dark2',
    random_state=1234
).generate_from_frequencies(freq_df.set_index('word')['freq'])

plt.imshow(wordcloud, interpolation='bilinear')
plt.axis('off')
plt.tight_layout(pad=0)
plt.show()

# Let the user choose the minimum frequency threshold using a form field
min_frequency = 4  #@param {type:"integer"}

# Step 7: Explore frequent terms with the chosen minimum frequency
frequent_terms = freq_df[freq_df['freq'] >= min_frequency]
print(f"Frequent terms with frequency >= {min_frequency}:")
print(frequent_terms)

# Create a Yes/No button for downloading the CSV
download_csv = True  #@param {type:"boolean"}

if download_csv:
    files.download("text.csv")
else:
    print("CSV file not downloaded.")
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
#      <input type="file" id="files-5181cd84-4656-4f2b-b3e6-97abb237c21f" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-5181cd84-4656-4f2b-b3e6-97abb237c21f">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# ...

# %%
# prompt: In the way you have incorporated "yes/no" button, provide the option to enter the wordcloud size. Modify the code wherever necessary

# Import necessary libraries
import nltk
import pandas as pd
import matplotlib.pyplot as plt
from wordcloud import WordCloud
from sklearn.feature_extraction.text import CountVectorizer
from nltk.corpus import stopwords
import string
from google.colab import files
import io

# Ensure NLTK stopwords are downloaded
nltk.download('stopwords')

# Step 1: Upload an Excel file in Google Colab
uploaded = files.upload()

# Step 2: Read the uploaded .xlsx file using pandas
# Assuming the text data is in a column named 'Text'
file_name = list(uploaded.keys())[0]  # Get the file name
df = pd.read_excel(io.BytesIO(uploaded[file_name]))

# Replace 'Text' with the actual column name containing the text data
# Ensure your Excel file has a column with this name or adjust as needed
Text = df['Text'].astype(str).tolist()

# Define custom stopwords
custom_stopwords = set(["blabla1", "blabla2"])

# Combine English stopwords with custom stopwords
stop_words = set(stopwords.words('english')).union(custom_stopwords)

# Function to preprocess text
def preprocess_text(text):
    # Convert to lowercase
    text = text.lower()
    # Remove numbers
    text = ''.join([char for char in text if not char.isdigit()])
    # Remove punctuation
    text = text.translate(str.maketrans('', '', string.punctuation))
    # Remove stopwords
    tokens = text.split()
    tokens = [word for word in tokens if word not in stop_words]
    return ' '.join(tokens)

# Step 3: Clean the text
cleaned_text = [preprocess_text(doc) for doc in Text]

# Step 4: Create a Term-Document Matrix using CountVectorizer
vectorizer = CountVectorizer()
term_doc_matrix = vectorizer.fit_transform(cleaned_text)

# Get the frequency of each word
term_freq = term_doc_matrix.toarray().sum(axis=0)
terms = vectorizer.get_feature_names_out()
freq_df = pd.DataFrame({'word': terms, 'freq': term_freq})

# Sort the DataFrame by frequency in descending order
freq_df = freq_df.sort_values(by='freq', ascending=False).reset_index(drop=True)

# Display the top 10 most frequent words
print(freq_df.head(10))

# Step 5: Save the frequency DataFrame to a CSV file
freq_df.to_csv("text.csv", index=False)

# Let the user choose the value of max_words using a form field
max_words = 2000  #@param {type:"integer"}


# Let the user choose the width of the word cloud using a form field
wordcloud_width = 800  #@param {type:"integer"}

# Let the user choose the height of the word cloud using a form field
wordcloud_height = 400  #@param {type:"integer"}


# Step 6: Generate the Word Cloud
plt.figure(figsize=(10, 8))
wordcloud = WordCloud(
    width=wordcloud_width,
    height=wordcloud_height,
    background_color='white',
    max_words=max_words,
    colormap='Dark2',
    random_state=1234
).generate_from_frequencies(freq_df.set_index('word')['freq'])

plt.imshow(wordcloud, interpolation='bilinear')
plt.axis('off')
plt.tight_layout(pad=0)
plt.show()

# Let the user choose the minimum frequency threshold using a form field
min_frequency = 4  #@param {type:"integer"}

# Step 7: Explore frequent terms with the chosen minimum frequency
frequent_terms = freq_df[freq_df['freq'] >= min_frequency]
print(f"Frequent terms with frequency >= {min_frequency}:")
print(frequent_terms)

# Create a Yes/No button for downloading the CSV
download_csv = True  #@param {type:"boolean"}

if download_csv:
    files.download("text.csv")
else:
    print("CSV file not downloaded.")
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
#      <input type="file" id="files-b5c2ff15-e656-4922-903f-1fb012963d3a" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-b5c2ff15-e656-4922-903f-1fb012963d3a">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# ...

# %%
# prompt: In the way you have incorporated "yes/no" button and other features, provide the option to upload file. Provide the upload button. Modify the code wherever necessary

import nltk
import pandas as pd
import matplotlib.pyplot as plt
from wordcloud import WordCloud
from sklearn.feature_extraction.text import CountVectorizer
from nltk.corpus import stopwords
import string
from google.colab import files
import io

# Import necessary libraries

# Ensure NLTK stopwords are downloaded
nltk.download('stopwords')

# Step 1: Upload an Excel file in Google Colab using a button
uploaded = files.upload()

if not uploaded:
    print("No file uploaded. Please upload an Excel file.")
else:
    # Step 2: Read the uploaded .xlsx file using pandas
    # Assuming the text data is in a column named 'Text'
    file_name = list(uploaded.keys())[0]  # Get the file name
    df = pd.read_excel(io.BytesIO(uploaded[file_name]))

    # Replace 'Text' with the actual column name containing the text data
    # Ensure your Excel file has a column with this name or adjust as needed
    Text = df['Text'].astype(str).tolist()

    # Define custom stopwords
    custom_stopwords = set(["blabla1", "blabla2"])

    # Combine English stopwords with custom stopwords
    stop_words = set(stopwords.words('english')).union(custom_stopwords)

    # Function to preprocess text
    def preprocess_text(text):
        # Convert to lowercase
        text = text.lower()
        # Remove numbers
        text = ''.join([char for char in text if not char.isdigit()])
        # Remove punctuation
        text = text.translate(str.maketrans('', '', string.punctuation))
        # Remove stopwords
        tokens = text.split()
        tokens = [word for word in tokens if word not in stop_words]
        return ' '.join(tokens)

    # Step 3: Clean the text
    cleaned_text = [preprocess_text(doc) for doc in Text]

    # Step 4: Create a Term-Document Matrix using CountVectorizer
    vectorizer = CountVectorizer()
    term_doc_matrix = vectorizer.fit_transform(cleaned_text)

    # Get the frequency of each word
    term_freq = term_doc_matrix.toarray().sum(axis=0)
    terms = vectorizer.get_feature_names_out()
    freq_df = pd.DataFrame({'word': terms, 'freq': term_freq})

    # Sort the DataFrame by frequency in descending order
    freq_df = freq_df.sort_values(by='freq', ascending=False).reset_index(drop=True)

    # Display the top 10 most frequent words
    print(freq_df.head(10))

    # Step 5: Save the frequency DataFrame to a CSV file
    freq_df.to_csv("text.csv", index=False)

    # Let the user choose the value of max_words using a form field
    max_words = 2  #@param {type:"integer"}


    # Let the user choose the width of the word cloud using a form field
    wordcloud_width = 800  #@param {type:"integer"}

    # Let the user choose the height of the word cloud using a form field
    wordcloud_height = 400  #@param {type:"integer"}


    # Step 6: Generate the Word Cloud
    plt.figure(figsize=(10, 8))
    wordcloud = WordCloud(
        width=wordcloud_width,
        height=wordcloud_height,
        background_color='white',
        max_words=max_words,
        colormap='Dark2',
        random_state=1234
    ).generate_from_frequencies(freq_df.set_index('word')['freq'])

    plt.imshow(wordcloud, interpolation='bilinear')
    plt.axis('off')
    plt.tight_layout(pad=0)
    plt.show()

    # Let the user choose the minimum frequency threshold using a form field
    min_frequency = 8  #@param {type:"integer"}

    # Step 7: Explore frequent terms with the chosen minimum frequency
    frequent_terms = freq_df[freq_df['freq'] >= min_frequency]
    print(f"Frequent terms with frequency >= {min_frequency}:")
    print(frequent_terms)

    # Create a Yes/No button for downloading the CSV
    download_csv = False  #@param {type:"boolean"}

    if download_csv:
        files.download("text.csv")
    else:
        print("CSV file not downloaded.")
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
#      <input type="file" id="files-174cf128-0113-438b-bbb8-99f5c8267df2" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-174cf128-0113-438b-bbb8-99f5c8267df2">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# ...
